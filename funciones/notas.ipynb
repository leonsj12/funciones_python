# %%
# Solicitar al usuario la cantidad de notas
cantidad_notas = int(input("Ingresa la cantidad de notas: "))
# Out:
# Ingresa la cantidad de notas: 5

# %%
# Inicializar la suma de las notas
suma_notas = 0

# %%
# Ciclo para ingresar las notas y sumarlas
for i in range(cantidad_notas):
    nota = float(input(f"Ingrese la nota {i + 1}: "))
    suma_notas += nota
# Out:
# Ingrese la nota 1: 4
# Ingrese la nota 2: 6
# Ingrese la nota 3: 7
# Ingrese la nota 4: 3
# Ingrese la nota 5: 10

# %%
# Calcular el promedio
promedio = suma_notas / cantidad_notas

# %%
# Imprimir el promedio
print("El promedio de las notas es:", promedio)
# Out:
# El promedio de las notas es: 6.0
